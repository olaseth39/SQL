# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/sqlRollingAverageData.xlsx')
df
# Out:
#     user_id tweet_date  tweet_count  rolling_avg_3d
# 0       111 2022-06-01            2            2.00
# 1       111 2022-06-02            1            1.50
# 2       111 2022-06-03            3            2.00
# 3       111 2022-06-04            4            2.67
# 4       111 2022-06-05            5            4.00
# 5       111 2022-06-06            4            4.33
# 6       111 2022-06-07            6            5.00
# 7       199 2022-06-01            7            7.00
# 8       199 2022-06-02            5            6.00
# 9       199 2022-06-03            9            7.00
# 10      199 2022-06-04            1            5.00
# 11      199 2022-06-05            8            6.00
# 12      199 2022-06-06            2            3.67
# 13      199 2022-06-07            2            4.00
# 14      254 2022-06-01            1            1.00
# 15      254 2022-06-02            1            1.00
# 16      254 2022-06-03            2            1.33
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         21 non-null     int64
#  1   tweet_date      21 non-null     datetime64[ns]
#  2   tweet_count     21 non-null     int64
#  3   rolling_avg_3d  21 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2)
# memory usage: 800.0 bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
#df['tweet_date'][:14]

# %% [markdown]
# Now Let's select our data for plotting

# %%
# data for tweet_date against rolling_avg
x = df.loc[7:13, 'tweet_date']
x_1 = df.loc[:6, 'tweet_date']
#y_3 = df.loc[:5, 'tweet_count']
y_1 = df.loc[:6, 'rolling_avg_3d']
x_2 = df.loc[7:13, 'tweet_date']
y_2 = df.loc[7:13, 'rolling_avg_3d']
x_3 = df.loc[14:, 'tweet_date']
y_3 = df.loc[14:, 'rolling_avg_3d']

# %%
plt.figure(figsize=[10, 4])

sns.lineplot(x=x_1, y=y_1, label='user_111')
sns.lineplot(x=x_2, y=y_2, label='user_199')
sns.lineplot(x=x_3, y=y_3, label='user_254')

plt.title('rolling_avg_3d against tweet_date')
plt.legend()
#sns.lineplot(x_3, y_4)

# %% [markdown]
# Let's select our data for the tweet_date against tweet_count

# %%
x_1 = df.loc[:6, 'tweet_date']
#y_3 = df.loc[:5, 'tweet_count']
y_1 = df.loc[:6, 'tweet_count']
x_2 = df.loc[7:13, 'tweet_date']
y_2 = df.loc[7:13, 'tweet_count']
x_3 = df.loc[14:, 'tweet_date']
y_3 = df.loc[14:, 'tweet_count']

# %%
plt.figure(figsize=[10, 4])

sns.lineplot(x=x_1, y=y_1, label='user_111')
sns.lineplot(x=x_2, y=y_2, label='user_199')
sns.lineplot(x=x_3, y=y_3, label='user_254')

plt.title('tweet_count against tweet_date')
plt.legend()
